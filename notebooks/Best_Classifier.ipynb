# %%
import numpy as np
import pandas as pd
from SimpleCV import *
from sklearn import svm
from sklearn import metrics
from sklearn.externals import joblib
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Best Classifier
#
# SVM turned out ot be the best classifier. We will export it here to use for the application.

# %%
# wordt niet hoger door normalizen
df = pd.read_csv("../dataset-numpy/dataset_analysis_normalized_v4.csv")
df.head()

# split df in data (X) and labels (y)
X, y = df.iloc[:,:-1], df.iloc[:,-1]

# create train and test data and labels
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.20, random_state=67)
df.describe()
# Out:
#         blob_angle    blob_area  blob_centroid_x  blob_centroid_y  \
# count  1920.000000  1920.000000      1920.000000      1920.000000
# mean      0.779948     0.386221         0.469217         0.467661
# std       0.368169     0.187824         0.139196         0.182193
# min       0.000000     0.000000         0.000000         0.000000
# 25%       0.863493     0.253482         0.378048         0.344453
# 50%       0.973220     0.341226         0.462067         0.459344
# 75%       1.000000     0.481894         0.552328         0.562653
# max       1.000000     1.000000         1.000000         1.000000
#
#         blob_width  centroid_bottom_is_empty  centroid_is_empty  \
# count  1920.000000               1920.000000        1920.000000
# mean      0.522865                  0.348958           0.295312
# std       0.101772                  0.476765           0.456302
# min       0.000000                  0.000000           0.000000
# ...

# %%
clf = svm.SVC(kernel ="rbf", C=1.2, gamma=0.171)
clf.fit(X_train, y_train)
score = clf.score(X_test, y_test)
print score

# %%
dataset = ["dataset_analysis_normalized_without_blob_width.csv",
           "dataset_analysis_v3.csv",
           "dataset_analysis_normalized_v3.csv",
           "dataset_analysis_normalized_with_contours.csv",
           "dataset_analysis_with_contours.csv",
           "dataset_analysis_without_blob_width.csv"
          ]

# %%
for dataset in datasets:
    scores = np.zeros((100))
    df = pd.read_csv(dataset)

    X, y = df.iloc[:,:-1], df.iloc[:,-1]

    # create train and test data and labels
    
    for i in range(100):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.20, random_state = i)


        clf = svm.SVC(kernel ="rbf", C=1.2, gamma=0.171)
        clf.fit(X_train, y_train)
        scores[i] = clf.score(X_test, y_test)
    
    print dataset
    print scores.mean()

    print scores.min()
    print scores.max()
# Out:
# ../dataset-numpy/dataset_analysis_normalized_v3.csv
# 0.979505208333
# ../dataset-numpy/dataset_analysis_normalized_without_blob_width.csv
# 0.97953125

# %%
joblib.dump(clf, 'svcModel.joblib')
